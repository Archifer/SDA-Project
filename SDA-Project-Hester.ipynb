# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd

# %%
fin = open('data/our_data.csv', 'r')
our = csv.DictReader(fin)
our_data = [row for row in our]

# %%
fin = open('data/our_data_Xbox.csv', 'r')
our = csv.DictReader(fin)
our_data_xbox = [row for row in our]

# %%
fin = open('data/our_data_PlayStation.csv', 'r')
our = csv.DictReader(fin)
our_data_ps = [row for row in our]

# %%
fin = open('data/our_data_Nintendo.csv', 'r')
our = csv.DictReader(fin)
our_data_nint = [row for row in our]

# %%
fin = open('data/our_data_PC.csv', 'r')
our = csv.DictReader(fin)
our_data_pc = [row for row in our]

# %%
our_title = 'title'
our_platform = 'platform'
our_score = 'score'
our_release_y = 'release_year'
our_release_m = 'release_month'
our_release_d = 'release_day'

our_rank = 'Rank'
our_genre = 'Genre'
our_publisher = 'Publisher'
our_NA = 'NA_Sales'
our_EU = 'EU_Sales'
our_JP = 'JP_Sales'
our_other = 'Other_Sales'
our_global = 'Global_Sales'


our_keys = [our_title, our_platform, our_score, our_release_y, our_release_m, our_release_d, our_rank, our_genre, \
            our_publisher, our_NA, our_EU, our_JP, our_other, our_global]

# %% [markdown]
# # Show plots of data to get an overview

# %%
def get_frequencies_for_key(key, data):
    freqs = dict()
    for row in data:
        if row[key] not in freqs:
            freqs[row[key]] = 1
        else:
            freqs[row[key]] += 1
    return freqs

def plot_with_dict(dictio, title, xlabel, ylabel="Frequency", colour=None):
    plt.bar(range(len(dictio)), list(dictio.values()), align='center', color=colour)
    plt.xticks(range(len(dictio)), list(dictio.keys()), rotation='vertical')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
def get_first_n_from_sorted(d, n):
    res = dict()
    sorted_dict = [(k, d[k]) for k in sorted(d, key=d.get, reverse=True)]
    for i in sorted_dict[:n]:
        res[i[0]] = i[1]
    return res

def sort_dict_by_key(d):
    res = dict()
    sorted_dict = sorted(d)
    for i in sorted_dict:
        res[i] = d[i]
    return res

def convert_dict_keys_to_floats(dictio):
    res = dict()
    for d in dictio:
        res[float(d)] = dictio[d]
    return res

# %%
plt.figure(figsize=(20, 15))
freqs_for_pl = get_frequencies_for_key(our_platform, our_data)
plot_with_dict(freqs_for_pl, "Number of games per platform", "Platform")

plt.figure(figsize=(20,15))
freqs_for_pu = get_frequencies_for_key(our_publisher, our_data)
plot_with_dict(freqs_for_pu, "Number of games per publisher", "Publisher")

print("*******\n Below is a top 20 of this plot, since this plot is not readable\n******* ")

plt.figure(figsize=(20, 15))
top20_pu = get_first_n_from_sorted(freqs_for_pu, 20)
plot_with_dict(top20_pu, "Top20 of games per publisher", "Publisher")

plt.figure(figsize=(20, 15))
freqs_for_gen = get_frequencies_for_key(our_genre, our_data)
plot_with_dict(freqs_for_gen, "Number of games per genre", "Genre")

plt.figure(figsize=(20, 15))
freqs_for_year = get_frequencies_for_key(our_release_y, our_data)
sorted_freqs_for_year = sort_dict_by_key(freqs_for_year)
plot_with_dict(sorted_freqs_for_year, "Number of games released per year", "Year")

plt.figure(figsize=(20, 15))
freqs_for_scores = get_frequencies_for_key(our_score, our_data)
freqs_for_scores = convert_dict_keys_to_floats(freqs_for_scores)
sorted_freqs_for_scores = sort_dict_by_key(freqs_for_scores)
plot_with_dict(sorted_freqs_for_scores, "Number of games per score", "Score")
# Out:
# *******
#  Below is a top 20 of this plot, since this plot is not readable
# *******

# %% [markdown]
# # Plots of data for the Xbox

# %%
plt.figure(figsize=(20, 15))
freqs_for_gen_x = get_frequencies_for_key(our_genre, our_data_xbox)
plot_with_dict(freqs_for_gen_x, "Number of games per genre on the Xbox", "Genre")

plt.figure(figsize=(20, 15))
freqs_for_pu_x = get_frequencies_for_key(our_publisher, our_data_xbox)
plot_with_dict(freqs_for_pu_x, "Number of games per publisher on the Xbox", "Publisher")

plt.figure(figsize=(20, 15))
top20_pu_x = get_first_n_from_sorted(freqs_for_pu_x, 20)
plot_with_dict(top20_pu_x, "Top20 of games per publisher on the Xbox", "Publisher")

plt.figure(figsize=(20, 15))
freqs_for_year_x = get_frequencies_for_key(our_release_y, our_data_xbox)
sorted_freqs_for_year_x = sort_dict_by_key(freqs_for_year_x)
plot_with_dict(sorted_freqs_for_year_x, "Number of games released per year on the Xbox", "Year")

plt.figure(figsize=(20, 15))
freqs_for_scores_x = get_frequencies_for_key(our_score, our_data_xbox)
freqs_for_scores_x = convert_dict_keys_to_floats(freqs_for_scores_x)
sorted_freqs_for_scores_x = sort_dict_by_key(freqs_for_scores_x)
plot_with_dict(sorted_freqs_for_scores_x, "Number of games per score on the Xbox", "Score")

# %% [markdown]
# # Plots of data for the PC

# %%
plt.figure(figsize=(20, 15))
freqs_for_gen_pc = get_frequencies_for_key(our_genre, our_data_pc)
plot_with_dict(freqs_for_gen_pc, "Number of games per genre on the PC", "Genre")

plt.figure(figsize=(20, 15))
freqs_for_pu_pc = get_frequencies_for_key(our_publisher, our_data_pc)
plot_with_dict(freqs_for_pu_pc, "Number of games per publisher on the PC", "Publisher")

plt.figure(figsize=(20, 15))
top20_pu_pc = get_first_n_from_sorted(freqs_for_pu_pc, 20)
plot_with_dict(top20_pu_pc, "Top20 of games per publisher on the PC", "Publisher")

plt.figure(figsize=(20, 15))
freqs_for_year_pc = get_frequencies_for_key(our_release_y, our_data_pc)
sorted_freqs_for_year_pc = sort_dict_by_key(freqs_for_year_pc)
plot_with_dict(sorted_freqs_for_year_pc, "Number of games released per year on the PC", "Year")

plt.figure(figsize=(20, 15))
freqs_for_scores_pc = get_frequencies_for_key(our_score, our_data_pc)
freqs_for_scores_pc = convert_dict_keys_to_floats(freqs_for_scores_pc)
sorted_freqs_for_scores_pc = sort_dict_by_key(freqs_for_scores_pc)
plot_with_dict(sorted_freqs_for_scores_pc, "Number of games per score on the PC", "Score")

# %% [markdown]
# # Plots of data for the playStation

# %%
plt.figure(figsize=(20, 15))
freqs_for_gen_ps = get_frequencies_for_key(our_genre, our_data_ps)
plot_with_dict(freqs_for_gen_ps, "Number of games per genre on the PlayStation", "Genre")

plt.figure(figsize=(20, 15))
freqs_for_pu_ps = get_frequencies_for_key(our_publisher, our_data_ps)
plot_with_dict(freqs_for_pu_ps, "Number of games per publisher on the PlayStation", "Publisher")

plt.figure(figsize=(20, 15))
top20_pu_ps = get_first_n_from_sorted(freqs_for_pu_ps, 20)
plot_with_dict(top20_pu_ps, "Top20 of games per publisher on the Playstation", "Publisher")

plt.figure(figsize=(20, 15))
freqs_for_year_ps = get_frequencies_for_key(our_release_y, our_data_ps)
sorted_freqs_for_year_ps = sort_dict_by_key(freqs_for_year_ps)
plot_with_dict(sorted_freqs_for_year_ps, "Number of games released per year on the PlayStation", "Year")

plt.figure(figsize=(20, 15))
freqs_for_scores_ps = get_frequencies_for_key(our_score, our_data_ps)
freqs_for_scores_ps = convert_dict_keys_to_floats(freqs_for_scores_ps)
sorted_freqs_for_scores_ps = sort_dict_by_key(freqs_for_scores_ps)
plot_with_dict(sorted_freqs_for_scores_ps, "Number of games per score on the PlayStation", "Score")

# %% [markdown]
# # Plots of data for the Nintendo

# %%
plt.figure(figsize=(20, 15))
freqs_for_gen_n = get_frequencies_for_key(our_genre, our_data_nint)
plot_with_dict(freqs_for_gen_n, "Number of games per genre on the Nintendo", "Genre")

plt.figure(figsize=(20, 15))
freqs_for_pu_n = get_frequencies_for_key(our_publisher, our_data_nint)
plot_with_dict(freqs_for_pu_n, "Number of games per publisher on the Nintendo", "Publisher")

plt.figure(figsize=(20, 15))
top20_pu_n = get_first_n_from_sorted(freqs_for_pu_n, 20)
plot_with_dict(top20_pu_n, "Top20 of games per publisher on the Nintendo", "Publisher")

plt.figure(figsize=(20, 15))
freqs_for_year_n = get_frequencies_for_key(our_release_y, our_data_nint)
sorted_freqs_for_year_n = sort_dict_by_key(freqs_for_year_n)
plot_with_dict(sorted_freqs_for_year_n, "Number of games released per year on the Nintendo", "Year")

plt.figure(figsize=(20, 15))
freqs_for_scores_n = get_frequencies_for_key(our_score, our_data_nint)
freqs_for_scores_n = convert_dict_keys_to_floats(freqs_for_scores_n)
sorted_freqs_for_scores_n = sort_dict_by_key(freqs_for_scores_n)
plot_with_dict(sorted_freqs_for_scores_n, "Number of games per score on the Nintendo", "Score")

# %% [markdown]
# # Big hits per year per quarter on all platforms

# %%
def find_max_saled_game_in_dict_with_key(dictio, key):
    max_val = 0.0
    max_row = None
    for row in dictio:
        if float(row[key]) > max_val:
            max_val = float(row[key])
            max_row = row
    if max_row == None:
        max_row = {our_title: '---------'}
    return max_row

quarter_1 = ['1', '2', '3']
quarter_2 = ['4', '5', '6']
quarter_3 = ['7', '8', '9']
quarter_4 = ['10', '11', '12']

all_big_hits = []
q1_big_hits = []
q2_big_hits = []
q3_big_hits = []
q4_big_hits = []


def get_bigHits_for_year(year, data, key):
    quarter1 = []
    quarter2 = []
    quarter3 = []
    quarter4 = []
    for row in data:
        if row[our_release_y] == year:
            if row[our_release_m] in quarter_1:
                quarter1.append(row)
            elif row[our_release_m] in quarter_2:
                quarter2.append(row)
            elif row[our_release_m] in quarter_3:
                quarter3.append(row)
            elif row[our_release_m] in quarter_4:
                quarter4.append(row)

    max1 = find_max_saled_game_in_dict_with_key(quarter1, key)
    max2 = find_max_saled_game_in_dict_with_key(quarter2, key)
    max3 = find_max_saled_game_in_dict_with_key(quarter3, key)
    max4 = find_max_saled_game_in_dict_with_key(quarter4, key)
    
    
    return max1, max2, max3, max4
    
    
years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', 
        '2010', '2011', '2012', '2013', '2014', '2015', '2016']

for y in years:
    big_hits_y = get_bigHits_for_year(y, our_data, our_global)
    print(y)
    kwrt = 1
    
    q1_big_hits.append(big_hits_y[0])
    q2_big_hits.append(big_hits_y[1])
    q3_big_hits.append(big_hits_y[2])
    q4_big_hits.append(big_hits_y[3])
    
    for bh in range(len(big_hits_y)):
        if big_hits_y[bh][our_title] != '---------':
            all_big_hits.append(big_hits_y[bh])
        print('Kwartaal', kwrt, ' : ', big_hits_y[bh][our_title])
        
        kwrt += 1
    
plt.figure(figsize=(20, 15))
freqs_for_gen_hits = get_frequencies_for_key(our_genre, all_big_hits)
plot_with_dict(freqs_for_gen_hits, "Number of big hit games per genre", "Genre")

plt.figure(figsize=(20, 15))
freqs_for_pu_hits = get_frequencies_for_key(our_publisher, all_big_hits)
plot_with_dict(freqs_for_pu_hits, "Number of big hit games per publisher", "Publisher")

plt.figure(figsize=(20, 15))
top20_pu_hits = get_first_n_from_sorted(freqs_for_pu_hits, 20)
plot_with_dict(top20_pu_hits, "Top20 of big hit games per publisher", "Publisher")

plt.figure(figsize=(20, 15))
freqs_for_scores_hits = get_frequencies_for_key(our_score, all_big_hits)
freqs_for_scores_hits = convert_dict_keys_to_floats(freqs_for_scores_hits)
sorted_freqs_for_scores_hits = sort_dict_by_key(freqs_for_scores_hits)
plot_with_dict(sorted_freqs_for_scores_hits, "Number of big hit games per score", "Score")
# Out:
# 2000
# Kwartaal 1  :  Pokemon Stadium
# Kwartaal 2  :  Perfect Dark
# Kwartaal 3  :  Tony Hawk's Pro Skater 2
# Kwartaal 4  :  Final Fantasy IX
# 2001
# Kwartaal 1  :  Onimusha: Warlords
# Kwartaal 2  :  Super Mario Advance
# Kwartaal 3  :  Madden NFL 2002
# Kwartaal 4  :  Grand Theft Auto III
# 2002
# Kwartaal 1  :  Hot Shots Golf 3
# Kwartaal 2  :  Medal of Honor: Frontline
# Kwartaal 3  :  Kingdom Hearts
# Kwartaal 4  :  Grand Theft Auto: Vice City
# 2003
# Kwartaal 1  :  The Getaway
# Kwartaal 2  :  Enter the Matrix
# Kwartaal 3  :  The Simpsons: Hit & Run
# Kwartaal 4  :  Need for Speed Underground
# 2004
# Kwartaal 1  :  Sonic Heroes
# Kwartaal 2  :  Spider-Man 2
# Kwartaal 3  :  Madden NFL 2005
# Kwartaal 4  :  Grand Theft Auto: San Andreas
# 2005
# Kwartaal 1  :  Gran Turismo 4
# Kwartaal 2  :  Midnight Club 3: DUB Edition
# Kwartaal 3  :  Madden NFL 06
# Kwartaal 4  :  Mario Kart DS
# 2006
# Kwartaal 1  :  The Elder Scrolls IV: Oblivion
# Kwartaal 2  :  New Super Mario Bros.
# Kwartaal 3  :  Cooking Mama
# Kwartaal 4  :  Wii Sports
# 2007
# Kwartaal 1  :  Donkey Kong Country
# Kwartaal 2  :  Mario Party 8
# Kwartaal 3  :  Brain Age 2: More Training in Minutes a Day
# Kwartaal 4  :  Super Mario Galaxy
# 2008
# Kwartaal 1  :  Super Smash Bros. Brawl
# Kwartaal 2  :  Mario Kart Wii
# Kwartaal 3  :  LEGO Batman: The Videogame
# Kwartaal 4  :  Call of Duty: World at War
# 2009
# Kwartaal 1  :  Resident Evil 5
# Kwartaal 2  :  The Sims 3
# Kwartaal 3  :  Wii Sports Resort
# Kwartaal 4  :  New Super Mario Bros. Wii
# 2010
# Kwartaal 1  :  Final Fantasy XIII
# Kwartaal 2  :  Super Mario Galaxy 2
# Kwartaal 3  :  Halo: Reach
# Kwartaal 4  :  Call of Duty: Black Ops
# 2011
# Kwartaal 1  :  LittleBigPlanet 2
# Kwartaal 2  :  L.A. Noire
# Kwartaal 3  :  Gears of War 3
# Kwartaal 4  :  Call of Duty: Modern Warfare 3
# 2012
# Kwartaal 1  :  Mario Party 9
# Kwartaal 2  :  Minecraft
# Kwartaal 3  :  New Super Mario Bros. 2
# Kwartaal 4  :  Call of Duty: Black Ops II
# 2013
# Kwartaal 1  :  Luigi's Mansion: Dark Moon
# Kwartaal 2  :  Animal Crossing: New Leaf
# Kwartaal 3  :  Grand Theft Auto V
# Kwartaal 4  :  Call of Duty: Ghosts
# 2014
# Kwartaal 1  :  Minecraft
# Kwartaal 2  :  Mario Kart 8
# Kwartaal 3  :  FIFA 15
# Kwartaal 4  :  Grand Theft Auto V
# 2015
# Kwartaal 1  :  Monster Hunter 4 Ultimate
# Kwartaal 2  :  Batman: Arkham Knight
# Kwartaal 3  :  FIFA 16
# Kwartaal 4  :  Fallout 4
# 2016
# Kwartaal 1  :  Tom Clancy's The Division
# Kwartaal 2  :  Uncharted 4: A Thief's End
# Kwartaal 3  :  FIFA 17
# Kwartaal 4  :  ---------

# %% [markdown]
# # Big hits per year per quarter on the Xbox

# %%
all_big_hits_x = []
q1_big_hits_x = []
q2_big_hits_x = []
q3_big_hits_x = []
q4_big_hits_x = []

for y in years:
    big_hits_y_x = get_bigHits_for_year(y, our_data_xbox, our_global)
    print(y)
    kwrt = 1
    
    q1_big_hits_x.append(big_hits_y_x[0])
    q2_big_hits_x.append(big_hits_y_x[1])
    q3_big_hits_x.append(big_hits_y_x[2])
    q4_big_hits_x.append(big_hits_y_x[3])
    
    for bh in range(len(big_hits_y_x)):
        if big_hits_y_x[bh][our_title] != '---------':
            all_big_hits_x.append(big_hits_y_x[bh])
        print('Kwartaal', kwrt, ' : ', big_hits_y_x[bh][our_title])
        
        kwrt += 1
        
        
plt.figure(figsize=(20, 15))
freqs_for_gen_hits_x = get_frequencies_for_key(our_genre, all_big_hits_x)
plot_with_dict(freqs_for_gen_hits_x, "Number of big hit games per genre on the Xbox", "Genre")

plt.figure(figsize=(20, 15))
freqs_for_pu_hits_x = get_frequencies_for_key(our_publisher, all_big_hits_x)
plot_with_dict(freqs_for_pu_hits_x, "Number of big hit games per publisher on the Xbox", "Publisher")

plt.figure(figsize=(20, 15))
freqs_for_scores_hits_x = get_frequencies_for_key(our_score, all_big_hits_x)
freqs_for_scores_hits_x = convert_dict_keys_to_floats(freqs_for_scores_hits_x)
sorted_freqs_for_scores_hits_x = sort_dict_by_key(freqs_for_scores_hits_x)
plot_with_dict(sorted_freqs_for_scores_hits_x, "Number of big hit games per score on the Xbox", "Score")
# Out:
# 2000
# Kwartaal 1  :  ---------
# Kwartaal 2  :  ---------
# Kwartaal 3  :  ---------
# Kwartaal 4  :  ---------
# 2001
# Kwartaal 1  :  ---------
# Kwartaal 2  :  ---------
# Kwartaal 3  :  ---------
# Kwartaal 4  :  Halo: Combat Evolved
# 2002
# Kwartaal 1  :  Star Wars: Obi-Wan
# Kwartaal 2  :  The Elder Scrolls III: Morrowind
# Kwartaal 3  :  Conflict: Desert Storm
# Kwartaal 4  :  Tom Clancy's Splinter Cell
# 2003
# Kwartaal 1  :  The Lord of the Rings: The Two Towers
# Kwartaal 2  :  Enter the Matrix
# Kwartaal 3  :  The Simpsons: Hit & Run
# Kwartaal 4  :  Need for Speed Underground
# 2004
# Kwartaal 1  :  Ninja Gaiden
# Kwartaal 2  :  Spider-Man 2
# Kwartaal 3  :  Fable
# Kwartaal 4  :  Halo 2
# 2005
# Kwartaal 1  :  MVP Baseball 2005
# Kwartaal 2  :  Grand Theft Auto: San Andreas
# Kwartaal 3  :  Madden NFL 06
# Kwartaal 4  :  Call of Duty 2
# 2006
# Kwartaal 1  :  The Elder Scrolls IV: Oblivion
# Kwartaal 2  :  Battlefield 2: Modern Combat
# Kwartaal 3  :  Saints Row
# Kwartaal 4  :  Gears of War
# 2007
# Kwartaal 1  :  Lost Planet: Extreme Condition
# Kwartaal 2  :  Forza Motorsport 2
# Kwartaal 3  :  Halo 3
# Kwartaal 4  :  Call of Duty 4: Modern Warfare
# 2008
# Kwartaal 1  :  Tom Clancy's Rainbow Six: Vegas 2
# Kwartaal 2  :  Grand Theft Auto IV
# Kwartaal 3  :  LEGO Batman: The Videogame
# Kwartaal 4  :  Call of Duty: World at War
# 2009
# Kwartaal 1  :  Resident Evil 5
# Kwartaal 2  :  Fight Night Round 4
# Kwartaal 3  :  Halo 3: ODST
# Kwartaal 4  :  Call of Duty: Modern Warfare 2
# 2010
# Kwartaal 1  :  Battlefield: Bad Company 2
# Kwartaal 2  :  Red Dead Redemption
# Kwartaal 3  :  Halo: Reach
# Kwartaal 4  :  Call of Duty: Black Ops
# 2011
# Kwartaal 1  :  Dead Space 2
# Kwartaal 2  :  L.A. Noire
# Kwartaal 3  :  Gears of War 3
# Kwartaal 4  :  Call of Duty: Modern Warfare 3
# 2012
# Kwartaal 1  :  Mass Effect 3
# Kwartaal 2  :  Minecraft
# Kwartaal 3  :  FIFA Soccer 13
# Kwartaal 4  :  Call of Duty: Black Ops II
# 2013
# Kwartaal 1  :  BioShock Infinite
# Kwartaal 2  :  Injustice: Gods Among Us
# Kwartaal 3  :  Grand Theft Auto V
# Kwartaal 4  :  Call of Duty: Ghosts
# 2014
# Kwartaal 1  :  Titanfall
# Kwartaal 2  :  Watch Dogs
# Kwartaal 3  :  Destiny
# Kwartaal 4  :  Call of Duty: Advanced Warfare
# 2015
# Kwartaal 1  :  Sunset Overdrive
# Kwartaal 2  :  Batman: Arkham Knight
# Kwartaal 3  :  FIFA 16
# Kwartaal 4  :  Halo 5: Guardians
# 2016
# Kwartaal 1  :  Tom Clancy's The Division
# Kwartaal 2  :  Overwatch
# Kwartaal 3  :  FIFA 17
# Kwartaal 4  :  ---------

# %% [markdown]
# # Big hits per year per quarter for the PlayStation

# %%
all_big_hits_ps = []
q1_big_hits_ps = []
q2_big_hits_ps = []
q3_big_hits_ps = []
q4_big_hits_ps = []

for y in years:
    big_hits_y_ps = get_bigHits_for_year(y, our_data_ps, our_global)
    print(y)
    kwrt = 1
    
    q1_big_hits_ps.append(big_hits_y_ps[0])
    q2_big_hits_ps.append(big_hits_y_ps[1])
    q3_big_hits_ps.append(big_hits_y_ps[2])
    q4_big_hits_ps.append(big_hits_y_ps[3])
    
    for bh in range(len(big_hits_y_ps)):
        if big_hits_y_ps[bh][our_title] != '---------':
            all_big_hits_ps.append(big_hits_y_ps[bh])
        print('Kwartaal', kwrt, ' : ', big_hits_y_ps[bh][our_title])
        
        kwrt += 1
        
        
plt.figure(figsize=(20, 15))
freqs_for_gen_hits_ps = get_frequencies_for_key(our_genre, all_big_hits_ps)
plot_with_dict(freqs_for_gen_hits_ps, "Number of big hit games per genre on the PlayStation", "Genre")

plt.figure(figsize=(20, 15))
freqs_for_pu_hits_ps = get_frequencies_for_key(our_publisher, all_big_hits_ps)
plot_with_dict(freqs_for_pu_hits_ps, "Number of big hit games per publisher on the PlayStation", "Publisher")

plt.figure(figsize=(20, 15))
freqs_for_scores_hits_ps = get_frequencies_for_key(our_score, all_big_hits_ps)
freqs_for_scores_hits_ps = convert_dict_keys_to_floats(freqs_for_scores_hits_ps)
sorted_freqs_for_scores_hits_ps = sort_dict_by_key(freqs_for_scores_hits_ps)
plot_with_dict(sorted_freqs_for_scores_hits_ps, "Number of big hit games per score on the PlayStation", "Score")
# Out:
# 2000
# Kwartaal 1  :  Syphon Filter 2
# Kwartaal 2  :  The Legend of Dragoon
# Kwartaal 3  :  Tony Hawk's Pro Skater 2
# Kwartaal 4  :  Final Fantasy IX
# 2001
# Kwartaal 1  :  Onimusha: Warlords
# Kwartaal 2  :  NBA Street
# Kwartaal 3  :  Madden NFL 2002
# Kwartaal 4  :  Grand Theft Auto III
# 2002
# Kwartaal 1  :  Hot Shots Golf 3
# Kwartaal 2  :  Medal of Honor: Frontline
# Kwartaal 3  :  Kingdom Hearts
# Kwartaal 4  :  Grand Theft Auto: Vice City
# 2003
# Kwartaal 1  :  The Getaway
# Kwartaal 2  :  Enter the Matrix
# Kwartaal 3  :  The Simpsons: Hit & Run
# Kwartaal 4  :  Need for Speed Underground
# 2004
# Kwartaal 1  :  Sonic Heroes
# Kwartaal 2  :  Spider-Man 2
# Kwartaal 3  :  Madden NFL 2005
# Kwartaal 4  :  Grand Theft Auto: San Andreas
# 2005
# Kwartaal 1  :  Gran Turismo 4
# Kwartaal 2  :  Midnight Club 3: DUB Edition
# Kwartaal 3  :  Madden NFL 06
# Kwartaal 4  :  Grand Theft Auto: Liberty City Stories
# 2006
# Kwartaal 1  :  Kingdom Hearts II
# Kwartaal 2  :  Grand Theft Auto: Liberty City Stories
# Kwartaal 3  :  Madden NFL 07
# Kwartaal 4  :  Final Fantasy XII
# 2007
# Kwartaal 1  :  Winning Eleven: Pro Evolution Soccer 2007
# Kwartaal 2  :  SingStar Pop
# Kwartaal 3  :  Monster Hunter Freedom 2
# Kwartaal 4  :  Call of Duty 4: Modern Warfare
# 2008
# Kwartaal 1  :  Pro Evolution Soccer 2008
# Kwartaal 2  :  Grand Theft Auto IV
# Kwartaal 3  :  Star Wars: The Force Unleashed
# Kwartaal 4  :  LittleBigPlanet
# 2009
# Kwartaal 1  :  Resident Evil 5
# Kwartaal 2  :  Monster Hunter Freedom Unite
# Kwartaal 3  :  Uncharted 2: Among Thieves
# Kwartaal 4  :  Call of Duty: Modern Warfare 2
# 2010
# Kwartaal 1  :  Final Fantasy XIII
# Kwartaal 2  :  Red Dead Redemption
# Kwartaal 3  :  FIFA Soccer 11
# Kwartaal 4  :  Call of Duty: Black Ops
# 2011
# Kwartaal 1  :  LittleBigPlanet 2
# Kwartaal 2  :  L.A. Noire
# Kwartaal 3  :  Dead Island
# Kwartaal 4  :  Call of Duty: Modern Warfare 3
# 2012
# Kwartaal 1  :  Final Fantasy XIII-2
# Kwartaal 2  :  Max Payne 3
# Kwartaal 3  :  FIFA Soccer 13
# Kwartaal 4  :  Call of Duty: Black Ops II
# 2013
# Kwartaal 1  :  God of War: Ascension
# Kwartaal 2  :  The Last of Us
# Kwartaal 3  :  Grand Theft Auto V
# Kwartaal 4  :  Call of Duty: Ghosts
# 2014
# Kwartaal 1  :  Minecraft
# Kwartaal 2  :  Watch Dogs
# Kwartaal 3  :  FIFA 15
# Kwartaal 4  :  Grand Theft Auto V
# 2015
# Kwartaal 1  :  Bloodborne
# Kwartaal 2  :  Batman: Arkham Knight
# Kwartaal 3  :  FIFA 16
# Kwartaal 4  :  Fallout 4
# 2016
# Kwartaal 1  :  Tom Clancy's The Division
# Kwartaal 2  :  Uncharted 4: A Thief's End
# Kwartaal 3  :  FIFA 17
# Kwartaal 4  :  ---------

# %% [markdown]
# # Big hits per year per quarter on the Nintendo

# %%
all_big_hits_n = []
q1_big_hits_n = []
q2_big_hits_n = []
q3_big_hits_n = []
q4_big_hits_n = []

for y in years:
    big_hits_y_n = get_bigHits_for_year(y, our_data_nint, our_global)
    print(y)
    kwrt = 1
    
    q1_big_hits_n.append(big_hits_y_n[0])
    q2_big_hits_n.append(big_hits_y_n[1])
    q3_big_hits_n.append(big_hits_y_n[2])
    q4_big_hits_n.append(big_hits_y_n[3])
    
    for bh in range(len(big_hits_y_n)):
        if big_hits_y_n[bh][our_title] != '---------':
            all_big_hits_n.append(big_hits_y_n[bh])
        print('Kwartaal', kwrt, ' : ', big_hits_y_n[bh][our_title])
        
        kwrt += 1
        
        
plt.figure(figsize=(20, 15))
freqs_for_gen_hits_n = get_frequencies_for_key(our_genre, all_big_hits_n)
plot_with_dict(freqs_for_gen_hits_n, "Number of big hit games per genre on the Nintendo", "Genre")

plt.figure(figsize=(20, 15))
freqs_for_pu_hits_n = get_frequencies_for_key(our_publisher, all_big_hits_n)
plot_with_dict(freqs_for_pu_hits_n, "Number of big hit games per publisher on the Nintendo", "Publisher")

plt.figure(figsize=(20, 15))
freqs_for_scores_hits_n = get_frequencies_for_key(our_score, all_big_hits_n)
freqs_for_scores_hits_n = convert_dict_keys_to_floats(freqs_for_scores_hits_n)
sorted_freqs_for_scores_hits_n = sort_dict_by_key(freqs_for_scores_hits_n)
plot_with_dict(sorted_freqs_for_scores_hits_n, "Number of big hit games per score on the Nintendo", "Score")
# Out:
# 2000
# Kwartaal 1  :  Pokemon Stadium
# Kwartaal 2  :  Perfect Dark
# Kwartaal 3  :  Mario Tennis
# Kwartaal 4  :  The Legend of Zelda: Majora's Mask
# 2001
# Kwartaal 1  :  Paper Mario
# Kwartaal 2  :  Super Mario Advance
# Kwartaal 3  :  Pac-Man Collection
# Kwartaal 4  :  Wario Land 4
# 2002
# Kwartaal 1  :  Sonic Advance
# Kwartaal 2  :  Dragon Ball Z: The Legacy of Goku
# Kwartaal 3  :  Madden NFL 2003
# Kwartaal 4  :  Kirby: Nightmare in Dream Land
# 2003
# Kwartaal 1  :  Sonic Advance 2
# Kwartaal 2  :  Donkey Kong Country
# Kwartaal 3  :  Final Fantasy Tactics Advance
# Kwartaal 4  :  Mario & Luigi: Superstar Saga
# 2004
# Kwartaal 1  :  Metroid: Zero Mission
# Kwartaal 2  :  Sonic Advance 3
# Kwartaal 3  :  Spider-Man 2
# Kwartaal 4  :  Kingdom Hearts: Chain of Memories
# 2005
# Kwartaal 1  :  The Legend of Zelda: The Minish Cap
# Kwartaal 2  :  LEGO Star Wars: The Video Game
# Kwartaal 3  :  Advance Wars: Dual Strike
# Kwartaal 4  :  Mario Kart DS
# 2006
# Kwartaal 1  :  Tetris DS
# Kwartaal 2  :  New Super Mario Bros.
# Kwartaal 3  :  Cooking Mama
# Kwartaal 4  :  Wii Sports
# 2007
# Kwartaal 1  :  Donkey Kong Country
# Kwartaal 2  :  Mario Party 8
# Kwartaal 3  :  Brain Age 2: More Training in Minutes a Day
# Kwartaal 4  :  Super Mario Galaxy
# 2008
# Kwartaal 1  :  Super Smash Bros. Brawl
# Kwartaal 2  :  Mario Kart Wii
# Kwartaal 3  :  Kirby Super Star Ultra
# Kwartaal 4  :  Animal Crossing: City Folk
# 2009
# Kwartaal 1  :  Rhythm Heaven
# Kwartaal 2  :  EA Sports Active
# Kwartaal 3  :  Wii Sports Resort
# Kwartaal 4  :  New Super Mario Bros. Wii
# 2010
# Kwartaal 1  :  Sonic Classic Collection
# Kwartaal 2  :  Super Mario Galaxy 2
# Kwartaal 3  :  Dragon Quest IX: Sentinels of the Starry Skies
# Kwartaal 4  :  Just Dance 2
# 2011
# Kwartaal 1  :  Mario Sports Mix
# Kwartaal 2  :  LEGO Pirates of the Caribbean: The Video Game
# Kwartaal 3  :  Dragon Quest Monsters: Joker 2
# Kwartaal 4  :  Mario Kart 7
# 2012
# Kwartaal 1  :  Mario Party 9
# Kwartaal 2  :  LEGO Batman 2: DC Super Heroes
# Kwartaal 3  :  New Super Mario Bros. 2
# Kwartaal 4  :  New Super Mario Bros. U
# 2013
# Kwartaal 1  :  Luigi's Mansion: Dark Moon
# Kwartaal 2  :  Animal Crossing: New Leaf
# Kwartaal 3  :  Mario & Luigi: Dream Team
# Kwartaal 4  :  Super Mario 3D World
# 2014
# Kwartaal 1  :  Donkey Kong Country: Tropical Freeze
# Kwartaal 2  :  Mario Kart 8
# Kwartaal 3  :  Hyrule Warriors
# Kwartaal 4  :  Captain Toad: Treasure Tracker
# 2015
# Kwartaal 1  :  Monster Hunter 4 Ultimate
# Kwartaal 2  :  Yoshi's Woolly World
# Kwartaal 3  :  Super Mario Maker
# Kwartaal 4  :  Splatoon
# 2016
# Kwartaal 1  :  The Legend of Zelda: Twilight Princess HD
# Kwartaal 2  :  Kirby: Planet Robobot
# Kwartaal 3  :  Metroid Prime: Federation Force
# Kwartaal 4  :  ---------

# %% [markdown]
# # Big hits per year per quarter on the PC

# %%
all_big_hits_pc = []
q1_big_hits_pc = []
q2_big_hits_pc = []
q3_big_hits_pc = []
q4_big_hits_pc = []

for y in years:
    big_hits_y_pc = get_bigHits_for_year(y, our_data_pc, our_global)
    print(y)
    kwrt = 1
    
    q1_big_hits_pc.append(big_hits_y_pc[0])
    q2_big_hits_pc.append(big_hits_y_pc[1])
    q3_big_hits_pc.append(big_hits_y_pc[2])
    q4_big_hits_pc.append(big_hits_y_pc[3])
    
    for bh in range(len(big_hits_y_pc)):
        if big_hits_y_pc[bh][our_title] != '---------':
            all_big_hits_pc.append(big_hits_y_pc[bh])
        print('Kwartaal', kwrt, ' : ', big_hits_y_pc[bh][our_title])
        
        kwrt += 1
        
        
plt.figure(figsize=(20, 15))
freqs_for_gen_hits_pc = get_frequencies_for_key(our_genre, all_big_hits_pc)
plot_with_dict(freqs_for_gen_hits_pc, "Number of big hit games per genre on the PC", "Genre")

plt.figure(figsize=(20, 15))
freqs_for_pu_hits_pc = get_frequencies_for_key(our_publisher, all_big_hits_pc)
plot_with_dict(freqs_for_pu_hits_pc, "Number of big hit games per publisher on the PC", "Publisher")

plt.figure(figsize=(20, 15))
freqs_for_scores_hits_pc = get_frequencies_for_key(our_score, all_big_hits_pc)
freqs_for_scores_hits_pc = convert_dict_keys_to_floats(freqs_for_scores_hits_pc)
sorted_freqs_for_scores_hits_pc = sort_dict_by_key(freqs_for_scores_hits_pc)
plot_with_dict(sorted_freqs_for_scores_hits_pc, "Number of big hit games per score on the PC", "Score")
# Out:
# 2000
# Kwartaal 1  :  The Sims
# Kwartaal 2  :  StarCraft
# Kwartaal 3  :  Diablo II
# Kwartaal 4  :  Command & Conquer: Red Alert 2
# 2001
# Kwartaal 1  :  The Sims: House Party
# Kwartaal 2  :  Microsoft Train Simulator
# Kwartaal 3  :  Diablo II: Lord of Destruction
# Kwartaal 4  :  The Sims: Hot Date
# 2002
# Kwartaal 1  :  Command & Conquer Renegade
# Kwartaal 2  :  The Sims: Vacation
# Kwartaal 3  :  Warcraft III: Reign of Chaos
# Kwartaal 4  :  The Sims: Unleashed
# 2003
# Kwartaal 1  :  SimCity 4
# Kwartaal 2  :  The Sims: Superstar
# Kwartaal 3  :  Warcraft III: The Frozen Throne
# Kwartaal 4  :  The Sims: Makin' Magic
# 2004
# Kwartaal 1  :  Far Cry
# Kwartaal 2  :  Harry Potter and the Prisoner of Azkaban
# Kwartaal 3  :  The Sims 2
# Kwartaal 4  :  World of Warcraft
# 2005
# Kwartaal 1  :  Silent Hunter III
# Kwartaal 2  :  Grand Theft Auto: San Andreas
# Kwartaal 3  :  The Sims 2: Nightlife
# Kwartaal 4  :  Age of Empires III
# 2006
# Kwartaal 1  :  The Sims 2: Open for Business
# Kwartaal 2  :  Titan Quest
# Kwartaal 3  :  Company of Heroes
# Kwartaal 4  :  Microsoft Flight Simulator X
# 2007
# Kwartaal 1  :  World of Warcraft: The Burning Crusade
# Kwartaal 2  :  Halo 2
# Kwartaal 3  :  BioShock
# Kwartaal 4  :  Call of Duty 4: Modern Warfare
# 2008
# Kwartaal 1  :  Sins of a Solar Empire
# Kwartaal 2  :  Mass Effect
# Kwartaal 3  :  Spore
# Kwartaal 4  :  World of Warcraft: Wrath of the Lich King
# 2009
# Kwartaal 1  :  Empire: Total War
# Kwartaal 2  :  The Sims 3
# Kwartaal 3  :  Dawn of Discovery
# Kwartaal 4  :  Call of Duty: Modern Warfare 2
# 2010
# Kwartaal 1  :  Battlefield: Bad Company 2
# Kwartaal 2  :  The Sims 3: Ambitions
# Kwartaal 3  :  Sid Meier's Civilization V
# Kwartaal 4  :  World of Warcraft: Cataclysm
# 2011
# Kwartaal 1  :  Crysis 2
# Kwartaal 2  :  The Witcher 2: Assassins of Kings
# Kwartaal 3  :  Deus Ex: Human Revolution
# Kwartaal 4  :  The Elder Scrolls V: Skyrim
# 2012
# Kwartaal 1  :  Mass Effect 3
# Kwartaal 2  :  Diablo III
# Kwartaal 3  :  Guild Wars 2
# Kwartaal 4  :  World of Warcraft: Mists of Pandaria
# 2013
# Kwartaal 1  :  StarCraft II: Heart of the Swarm
# Kwartaal 2  :  Star Wars: The Old Republic
# Kwartaal 3  :  Total War: Rome II
# Kwartaal 4  :  Battlefield 4
# 2014
# Kwartaal 1  :  The Elder Scrolls Online
# Kwartaal 2  :  Wolfenstein: The New Order
# Kwartaal 3  :  The Sims 4
# Kwartaal 4  :  Dragon Age: Inquisition
# 2015
# Kwartaal 1  :  Total War: Attila
# Kwartaal 2  :  Grand Theft Auto V
# Kwartaal 3  :  Metal Gear Solid V: The Phantom Pain
# Kwartaal 4  :  Fallout 4
# 2016
# Kwartaal 1  :  Tom Clancy's The Division
# Kwartaal 2  :  Overwatch
# Kwartaal 3  :  World of Warcraft: Legion
# Kwartaal 4  :  ---------
